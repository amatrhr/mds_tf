# %%
## note these to add w/Poetry to the Dockerfile
# %pip install pandas
# %pip install networkx
# %pip install scipy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 20.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (2.8.5)
# WARNING: You are using pip version 20.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (1.9.0)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.22.4)
# WARNING: You are using pip version 20.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
url = 'http://cs.bc.edu/~prudhome/AAPLD/animal-similarity.csv'

raw_dataset = pd.read_csv(url, index_col=0)
list_of_animal_pairs = raw_dataset.index.str.split('~')

# %%
animal_pair_data = pd.DataFrame.from_records(list_of_animal_pairs, columns=['first_animal', 'second_animal'], index= raw_dataset.index)

# %%
animal_pairs.sort_values(by = ['first_animal', 'second_animal'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 animal_pairs.sort_values(by = ['first_animal', 'second_animal'], inplace=True)
#
# NameError: name 'animal_pairs' is not defined

# %%
unique_animals = set(animal_pairs.first_animal).union(animal_pairs.second_animal)

# %%
animal_pairs = nx.Graph()
animal_pairs.add_nodes_from(unique_animals)
animal_pairs.add_edges_from(list_of_animal_pairs)

# %%
low_degree=[k for k,v in animal_pairs.degree._nodes.items() if len(v) < 32]

# %%
animal_pairs.remove_nodes_from(low_degree)

# %%
fig, ax = plt.subplots(figsize=(32,32))
nx.draw(animal_pairs, with_labels=True, ax=ax)

plt.show()

# %%
connected_list = [x for x in animal_pairs.nodes]

# %%
# try the small list, or, failing that, just the apes

# %%
smaller_animal_pair_data=animal_pair_data.loc[animal_pair_data['first_animal' ].isin( connected_list) | animal_pair_data['second_animal' ].isin( connected_list) ]

# %% [markdown]
# ![image.png](attachment:image.png)
# From Kruskal, 1964

# %% [markdown]
# Idea is to follow these steps,
